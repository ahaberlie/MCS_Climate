# %% [markdown]
# # Download the files needed for this analysis into the data folder
#
# ## Manual option (not recommended, use automated method below)

# %%
from download_files import download, download_geography

#follow the download links and put the netcdfs in the folder of your choice

#modify the code below to reflect these changes
download(analysis='mcs_days', subset='historical_monthly', print_urls=True)
download(analysis='mcs_days', subset='future_4p5_monthly', print_urls=True)
download(analysis='mcs_days', subset='future_8p5_monthly', print_urls=True)
download(analysis='mcs_days', subset='future_8p5_monthly', print_urls=True)
download_geography(print_urls=True)
# Out:
# https://svrimg.niu.edu/climc23/mcs_days/historical_monthly/monthly_mcs_days_historical_1990-1991.nc
# https://svrimg.niu.edu/climc23/mcs_days/historical_monthly/monthly_mcs_days_historical_1991-1992.nc
# https://svrimg.niu.edu/climc23/mcs_days/historical_monthly/monthly_mcs_days_historical_1992-1993.nc
# https://svrimg.niu.edu/climc23/mcs_days/historical_monthly/monthly_mcs_days_historical_1993-1994.nc
# https://svrimg.niu.edu/climc23/mcs_days/historical_monthly/monthly_mcs_days_historical_1994-1995.nc
# https://svrimg.niu.edu/climc23/mcs_days/historical_monthly/monthly_mcs_days_historical_1995-1996.nc
# https://svrimg.niu.edu/climc23/mcs_days/historical_monthly/monthly_mcs_days_historical_1996-1997.nc
# https://svrimg.niu.edu/climc23/mcs_days/historical_monthly/monthly_mcs_days_historical_1997-1998.nc
# https://svrimg.niu.edu/climc23/mcs_days/historical_monthly/monthly_mcs_days_historical_1998-1999.nc
# https://svrimg.niu.edu/climc23/mcs_days/historical_monthly/monthly_mcs_days_historical_1999-2000.nc
# https://svrimg.niu.edu/climc23/mcs_days/historical_monthly/monthly_mcs_days_historical_2000-2001.nc
# https://svrimg.niu.edu/climc23/mcs_days/historical_monthly/monthly_mcs_days_historical_2001-2002.nc
# https://svrimg.niu.edu/climc23/mcs_days/historical_monthly/monthly_mcs_days_historical_2002-2003.nc
# https://svrimg.niu.edu/climc23/mcs_days/historical_monthly/monthly_mcs_days_historical_2003-2004.nc
# https://svrimg.niu.edu/climc23/mcs_days/historical_monthly/monthly_mcs_days_historical_2004-2005.nc
# https://svrimg.niu.edu/climc23/mcs_days/future_4p5_monthly/monthly_mcs_days_future_4p5_2085-2086.nc
# https://svrimg.niu.edu/climc23/mcs_days/future_4p5_monthly/monthly_mcs_days_future_4p5_2086-2087.nc
# https://svrimg.niu.edu/climc23/mcs_days/future_4p5_monthly/monthly_mcs_days_future_4p5_2087-2088.nc
# https://svrimg.niu.edu/climc23/mcs_days/future_4p5_monthly/monthly_mcs_days_future_4p5_2088-2089.nc
# https://svrimg.niu.edu/climc23/mcs_days/future_4p5_monthly/monthly_mcs_days_future_4p5_2089-2090.nc
# https://svrimg.niu.edu/climc23/mcs_days/future_4p5_monthly/monthly_mcs_days_future_4p5_2090-2091.nc
# https://svrimg.niu.edu/climc23/mcs_days/future_4p5_monthly/monthly_mcs_days_future_4p5_2091-2092.nc
# https://svrimg.niu.edu/climc23/mcs_days/future_4p5_monthly/monthly_mcs_days_future_4p5_2092-2093.nc
# https://svrimg.niu.edu/climc23/mcs_days/future_4p5_monthly/monthly_mcs_days_future_4p5_2093-2094.nc
# https://svrimg.niu.edu/climc23/mcs_days/future_4p5_monthly/monthly_mcs_days_future_4p5_2094-2095.nc
# https://svrimg.niu.edu/climc23/mcs_days/future_4p5_monthly/monthly_mcs_days_future_4p5_2095-2096.nc
# https://svrimg.niu.edu/climc23/mcs_days/future_4p5_monthly/monthly_mcs_days_future_4p5_2096-2097.nc
# https://svrimg.niu.edu/climc23/mcs_days/future_4p5_monthly/monthly_mcs_days_future_4p5_2097-2098.nc
# https://svrimg.niu.edu/climc23/mcs_days/future_4p5_monthly/monthly_mcs_days_future_4p5_2098-2099.nc
# https://svrimg.niu.edu/climc23/mcs_days/future_4p5_monthly/monthly_mcs_days_future_4p5_2099-2100.nc
# https://svrimg.niu.edu/climc23/mcs_days/future_8p5_monthly/monthly_mcs_days_future_8p5_2085-2086.nc
# https://svrimg.niu.edu/climc23/mcs_days/future_8p5_monthly/monthly_mcs_days_future_8p5_2086-2087.nc
# https://svrimg.niu.edu/climc23/mcs_days/future_8p5_monthly/monthly_mcs_days_future_8p5_2087-2088.nc
# https://svrimg.niu.edu/climc23/mcs_days/future_8p5_monthly/monthly_mcs_days_future_8p5_2088-2089.nc
# https://svrimg.niu.edu/climc23/mcs_days/future_8p5_monthly/monthly_mcs_days_future_8p5_2089-2090.nc
# https://svrimg.niu.edu/climc23/mcs_days/future_8p5_monthly/monthly_mcs_days_future_8p5_2090-2091.nc
# https://svrimg.niu.edu/climc23/mcs_days/future_8p5_monthly/monthly_mcs_days_future_8p5_2091-2092.nc
# https://svrimg.niu.edu/climc23/mcs_days/future_8p5_monthly/monthly_mcs_days_future_8p5_2092-2093.nc
# https://svrimg.niu.edu/climc23/mcs_days/future_8p5_monthly/monthly_mcs_days_future_8p5_2093-2094.nc
# https://svrimg.niu.edu/climc23/mcs_days/future_8p5_monthly/monthly_mcs_days_future_8p5_2094-2095.nc
# https://svrimg.niu.edu/climc23/mcs_days/future_8p5_monthly/monthly_mcs_days_future_8p5_2095-2096.nc
# https://svrimg.niu.edu/climc23/mcs_days/future_8p5_monthly/monthly_mcs_days_future_8p5_2096-2097.nc
# https://svrimg.niu.edu/climc23/mcs_days/future_8p5_monthly/monthly_mcs_days_future_8p5_2097-2098.nc
# https://svrimg.niu.edu/climc23/mcs_days/future_8p5_monthly/monthly_mcs_days_future_8p5_2098-2099.nc
# https://svrimg.niu.edu/climc23/mcs_days/future_8p5_monthly/monthly_mcs_days_future_8p5_2099-2100.nc
# https://svrimg.niu.edu/climc23/mcs_days/future_8p5_monthly/monthly_mcs_days_future_8p5_2085-2086.nc
# https://svrimg.niu.edu/climc23/mcs_days/future_8p5_monthly/monthly_mcs_days_future_8p5_2086-2087.nc
# https://svrimg.niu.edu/climc23/mcs_days/future_8p5_monthly/monthly_mcs_days_future_8p5_2087-2088.nc
# https://svrimg.niu.edu/climc23/mcs_days/future_8p5_monthly/monthly_mcs_days_future_8p5_2088-2089.nc
# https://svrimg.niu.edu/climc23/mcs_days/future_8p5_monthly/monthly_mcs_days_future_8p5_2089-2090.nc
# https://svrimg.niu.edu/climc23/mcs_days/future_8p5_monthly/monthly_mcs_days_future_8p5_2090-2091.nc
# https://svrimg.niu.edu/climc23/mcs_days/future_8p5_monthly/monthly_mcs_days_future_8p5_2091-2092.nc
# https://svrimg.niu.edu/climc23/mcs_days/future_8p5_monthly/monthly_mcs_days_future_8p5_2092-2093.nc
# https://svrimg.niu.edu/climc23/mcs_days/future_8p5_monthly/monthly_mcs_days_future_8p5_2093-2094.nc
# https://svrimg.niu.edu/climc23/mcs_days/future_8p5_monthly/monthly_mcs_days_future_8p5_2094-2095.nc
# https://svrimg.niu.edu/climc23/mcs_days/future_8p5_monthly/monthly_mcs_days_future_8p5_2095-2096.nc
# https://svrimg.niu.edu/climc23/mcs_days/future_8p5_monthly/monthly_mcs_days_future_8p5_2096-2097.nc
# https://svrimg.niu.edu/climc23/mcs_days/future_8p5_monthly/monthly_mcs_days_future_8p5_2097-2098.nc
# https://svrimg.niu.edu/climc23/mcs_days/future_8p5_monthly/monthly_mcs_days_future_8p5_2098-2099.nc
# https://svrimg.niu.edu/climc23/mcs_days/future_8p5_monthly/monthly_mcs_days_future_8p5_2099-2100.nc
# https://svrimg.niu.edu/npjcas23/CONUS.cpg
# https://svrimg.niu.edu/npjcas23/CONUS.dbf
# https://svrimg.niu.edu/npjcas23/CONUS.prj
# https://svrimg.niu.edu/npjcas23/CONUS.sbn
# https://svrimg.niu.edu/npjcas23/CONUS.sbx
# https://svrimg.niu.edu/npjcas23/CONUS.shp
# https://svrimg.niu.edu/npjcas23/CONUS.shp.xml
# https://svrimg.niu.edu/npjcas23/CONUS.shx

# %% [markdown]
# ## Automated option (recommended)

# %%
from download_files import download, download_geography

#This will automatically create directories and download the files for you
download(analysis='mcs_days', subset='historical_monthly', data_dir="../data", verbose=True, create_dirs=True)
download(analysis='mcs_days', subset='future_4p5_monthly', data_dir="../data", verbose=True,  create_dirs=True)
download(analysis='mcs_days', subset='future_8p5_monthly', data_dir="../data", verbose=True,  create_dirs=True) 
download_geography(data_dir="../data", verbose=True, create_dirs=True)
# Out:
# ../data/mcs_days/historical_monthly/monthly_mcs_days_historical_1990-1991.nc exists
# ../data/mcs_days/historical_monthly/monthly_mcs_days_historical_1991-1992.nc exists
# ../data/mcs_days/historical_monthly/monthly_mcs_days_historical_1992-1993.nc exists
# ../data/mcs_days/historical_monthly/monthly_mcs_days_historical_1993-1994.nc exists
# ../data/mcs_days/historical_monthly/monthly_mcs_days_historical_1994-1995.nc exists
# ../data/mcs_days/historical_monthly/monthly_mcs_days_historical_1995-1996.nc exists
# ../data/mcs_days/historical_monthly/monthly_mcs_days_historical_1996-1997.nc exists
# ../data/mcs_days/historical_monthly/monthly_mcs_days_historical_1997-1998.nc exists
# ../data/mcs_days/historical_monthly/monthly_mcs_days_historical_1998-1999.nc exists
# ../data/mcs_days/historical_monthly/monthly_mcs_days_historical_1999-2000.nc exists
# ../data/mcs_days/historical_monthly/monthly_mcs_days_historical_2000-2001.nc exists
# ../data/mcs_days/historical_monthly/monthly_mcs_days_historical_2001-2002.nc exists
# ../data/mcs_days/historical_monthly/monthly_mcs_days_historical_2002-2003.nc exists
# ../data/mcs_days/historical_monthly/monthly_mcs_days_historical_2003-2004.nc exists
# ../data/mcs_days/historical_monthly/monthly_mcs_days_historical_2004-2005.nc exists
# ../data/mcs_days/future_4p5_monthly/monthly_mcs_days_future_4p5_2085-2086.nc exists
# ../data/mcs_days/future_4p5_monthly/monthly_mcs_days_future_4p5_2086-2087.nc exists
# ../data/mcs_days/future_4p5_monthly/monthly_mcs_days_future_4p5_2087-2088.nc exists
# ../data/mcs_days/future_4p5_monthly/monthly_mcs_days_future_4p5_2088-2089.nc exists
# ../data/mcs_days/future_4p5_monthly/monthly_mcs_days_future_4p5_2089-2090.nc exists
# ../data/mcs_days/future_4p5_monthly/monthly_mcs_days_future_4p5_2090-2091.nc exists
# ../data/mcs_days/future_4p5_monthly/monthly_mcs_days_future_4p5_2091-2092.nc exists
# ../data/mcs_days/future_4p5_monthly/monthly_mcs_days_future_4p5_2092-2093.nc exists
# ../data/mcs_days/future_4p5_monthly/monthly_mcs_days_future_4p5_2093-2094.nc exists
# ../data/mcs_days/future_4p5_monthly/monthly_mcs_days_future_4p5_2094-2095.nc exists
# ../data/mcs_days/future_4p5_monthly/monthly_mcs_days_future_4p5_2095-2096.nc exists
# ../data/mcs_days/future_4p5_monthly/monthly_mcs_days_future_4p5_2096-2097.nc exists
# ../data/mcs_days/future_4p5_monthly/monthly_mcs_days_future_4p5_2097-2098.nc exists
# ../data/mcs_days/future_4p5_monthly/monthly_mcs_days_future_4p5_2098-2099.nc exists
# ../data/mcs_days/future_4p5_monthly/monthly_mcs_days_future_4p5_2099-2100.nc exists
# ../data/mcs_days/future_8p5_monthly/monthly_mcs_days_future_8p5_2085-2086.nc exists
# ../data/mcs_days/future_8p5_monthly/monthly_mcs_days_future_8p5_2086-2087.nc exists
# ../data/mcs_days/future_8p5_monthly/monthly_mcs_days_future_8p5_2087-2088.nc exists
# ../data/mcs_days/future_8p5_monthly/monthly_mcs_days_future_8p5_2088-2089.nc exists
# ../data/mcs_days/future_8p5_monthly/monthly_mcs_days_future_8p5_2089-2090.nc exists
# ../data/mcs_days/future_8p5_monthly/monthly_mcs_days_future_8p5_2090-2091.nc exists
# ../data/mcs_days/future_8p5_monthly/monthly_mcs_days_future_8p5_2091-2092.nc exists
# ../data/mcs_days/future_8p5_monthly/monthly_mcs_days_future_8p5_2092-2093.nc exists
# ../data/mcs_days/future_8p5_monthly/monthly_mcs_days_future_8p5_2093-2094.nc exists
# ../data/mcs_days/future_8p5_monthly/monthly_mcs_days_future_8p5_2094-2095.nc exists
# ../data/mcs_days/future_8p5_monthly/monthly_mcs_days_future_8p5_2095-2096.nc exists
# ../data/mcs_days/future_8p5_monthly/monthly_mcs_days_future_8p5_2096-2097.nc exists
# ../data/mcs_days/future_8p5_monthly/monthly_mcs_days_future_8p5_2097-2098.nc exists
# ../data/mcs_days/future_8p5_monthly/monthly_mcs_days_future_8p5_2098-2099.nc exists
# ../data/mcs_days/future_8p5_monthly/monthly_mcs_days_future_8p5_2099-2100.nc exists
# ../data/geog/CONUS.cpg exists
# ../data/geog/CONUS.dbf exists
# ../data/geog/CONUS.prj exists
# ../data/geog/CONUS.sbn exists
# ../data/geog/CONUS.sbx exists
# ../data/geog/CONUS.shp exists
# ../data/geog/CONUS.shp.xml exists
# ../data/geog/CONUS.shx exists
